# %%
# ==========================================
# Import Libraries
# ==========================================
import pandas as pd          # For data handling and analysis
import numpy as np           # Optional, useful for numerical operations

# ==========================================
# Load 1st Dataset
# (Using the exact path from the upload)
# ==========================================
df1 = pd.read_csv("stats (4).csv")

# ==========================================
# Display the first few rows to verify load
# ==========================================
df1.head()
# Out:
#   last_name, first_name  player_id  year  p_formatted_ip   pa  hit  home_run  \
# 0      Parker, Mitchell     680730  2025           164.2  725  178        25
# 1       Hendricks, Kyle     543294  2025           164.2  695  167        25
# 2            Lugo, Seth     607625  2024           206.2  836  177        16
# 3   Arrighetti, Spencer     681293  2024           145.0  632  139        21
# 4            Woo, Bryan     693433  2025           186.2  731  137        26
#
#    strikeout  k_percent  bb_percent  ...  fs_avg_break_z  n_kn_formatted  \
# 0        103       14.2         8.0  ...           -28.5             NaN
# 1        114       16.4         6.2  ...             NaN             NaN
# 2        181       21.7         5.7  ...           -32.4             NaN
# 3        171       27.1        10.3  ...             NaN             NaN
# 4        198       27.1         4.9  ...             NaN             NaN
#
#    kn_avg_speed  kn_avg_spin  kn_avg_break_x  kn_avg_break_z  st_avg_speed  \
# 0           NaN          NaN             NaN             NaN           NaN
# 1           NaN          NaN             NaN             NaN           NaN
# 2           NaN          NaN             NaN             NaN          82.1
# 3           NaN          NaN             NaN             NaN          80.8
# 4           NaN          NaN             NaN             NaN          85.1
#
#    st_avg_spin  st_avg_break_x  st_avg_break_z
# 0          NaN             NaN             NaN
# 1          NaN             NaN             NaN
# 2       2843.0            13.5           -37.9
# 3       2800.0            14.7           -40.5
# 4       2485.0            10.6           -34.0
#
# [5 rows x 87 columns]

# %%
# ==========================================
# 1. Column Names
# ==========================================
print("COLUMN NAMES:")
print(df1.columns.tolist())
print("\n" + "="*60 + "\n")

# ==========================================
# 2. Data Types
# ==========================================
print("DATA TYPES:")
print(df1.dtypes)
print("\n" + "="*60 + "\n")

# ==========================================
# 3. Column Descriptions (summary statistics)
#    Works for both numeric & categorical features
# ==========================================
print("SUMMARY STATISTICS:")
print(df1.describe(include='all').transpose())
print("\n" + "="*60 + "\n")

# ==========================================
# 4. Unique Values (counts + percentages)
# ==========================================
print("UNIQUE VALUE COUNTS AND PERCENTS:\n")
unique_summary = {}

for col in df1.columns:
    unique_count = df1[col].nunique(dropna=False)
    percent_unique = (unique_count / len(df1)) * 100
    
    unique_summary[col] = {
        "unique_count": unique_count,
        "percent_unique": percent_unique
    }

unique_df = pd.DataFrame(unique_summary).transpose()
print(unique_df)
print("\n" + "="*60 + "\n")

# ==========================================
# 5. Value Ranges (for numeric columns)
# ==========================================
print("RANGES OF VALUES (NUMERIC COLUMNS):\n")
numeric_cols = df1.select_dtypes(include=[np.number]).columns

range_summary = pd.DataFrame({
    "min": df1[numeric_cols].min(),
    "max": df1[numeric_cols].max(),
    "range": df1[numeric_cols].max() - df1[numeric_cols].min()
})

print(range_summary)
print("\n" + "="*60 + "\n")

# ==========================================
# Done — dataset overview complete
# ==========================================
# Out:
# COLUMN NAMES:
# ['last_name, first_name', 'player_id', 'year', 'p_formatted_ip', 'pa', 'hit', 'home_run', 'strikeout', 'k_percent', 'bb_percent', 'batting_avg', 'slg_percent', 'on_base_percent', 'on_base_plus_slg', 'p_earned_run', 'p_run', 'p_out', 'p_win', 'p_loss', 'p_era', 'p_lob', 'p_rbi', 'p_ab_scoring', 'p_called_strike', 'p_swinging_strike', 'p_total_ball', 'p_total_strike', 'p_total_swinging_strike', 'p_inh_runner', 'xba', 'xslg', 'woba', 'xwoba', 'xobp', 'sweet_spot_percent', 'barrel_batted_rate', 'solidcontact_percent', 'hard_hit_percent', 'avg_best_speed', 'avg_hyper_speed', 'whiff_percent', 'swing_percent', 'n_ff_formatted', 'ff_avg_speed', 'ff_avg_spin', 'ff_avg_break_x', 'ff_avg_break_z', 'ff_range_speed', 'n_sl_formatted', 'sl_avg_speed', 'sl_avg_spin', 'sl_avg_break_x', 'sl_avg_break_z', 'n_ch_formatted', 'ch_avg_speed', 'ch_avg_spin', 'ch_avg_break_x', 'ch_avg_break_z', 'n_cu_formatted', 'cu_avg_speed', 'cu_avg_spin', 'cu_avg_break_x', 'cu_avg_break_z', 'n_si_formatted', 'si_avg_speed', 'si_avg_spin', 'si_avg_break_x', 'si_avg_break_z', 'n_fc_formatted', 'fc_avg_speed', 'fc_avg_spin', 'fc_avg_break_x', 'fc_avg_break_z', 'n_fs_formatted', 'fs_avg_speed', 'fs_avg_spin', 'fs_avg_break_x', 'fs_avg_break_z', 'n_kn_formatted', 'kn_avg_speed', 'kn_avg_spin', 'kn_avg_break_x', 'kn_avg_break_z', 'st_avg_speed', 'st_avg_spin', 'st_avg_break_x', 'st_avg_break_z']
#
# ============================================================
#
# DATA TYPES:
# last_name, first_name     object
# player_id                  int64
# year                       int64
# p_formatted_ip           float64
# pa                         int64
#                           ...
# kn_avg_break_z           float64
# st_avg_speed             float64
# st_avg_spin              float64
# st_avg_break_x           float64
# st_avg_break_z           float64
# Length: 87, dtype: object
#
# ============================================================
#
# SUMMARY STATISTICS:
#                        count unique               top freq           mean  \
# last_name, first_name    214    152  Parker, Mitchell    2            NaN
# player_id              214.0    NaN               NaN  NaN  634485.074766
# year                   214.0    NaN               NaN  NaN         2024.5
# p_formatted_ip         214.0    NaN               NaN  NaN     159.271495
# pa                     214.0    NaN               NaN  NaN     666.766355
# ...                      ...    ...               ...  ...            ...
# kn_avg_break_z           2.0    NaN               NaN  NaN         -46.45
# st_avg_speed           101.0    NaN               NaN  NaN      82.193069
# st_avg_spin            101.0    NaN               NaN  NaN    2536.376238
# st_avg_break_x         101.0    NaN               NaN  NaN       8.487129
# st_avg_break_z         101.0    NaN               NaN  NaN     -40.421782
#
#                                std       min        25%       50%        75%  \
# last_name, first_name          NaN       NaN        NaN       NaN        NaN
# player_id              54492.84413  434378.0  607068.75  656605.0  669905.75
# year                      0.501172    2024.0     2024.0    2024.5     2025.0
# p_formatted_ip           22.384579     111.0      141.4     162.1      176.1
# pa                       86.300934     503.0      592.0     683.5      730.5
# ...                            ...       ...        ...       ...        ...
# kn_avg_break_z            4.454773     -49.6    -48.025    -46.45    -44.875
# st_avg_speed              2.656474      72.6       80.6      82.3       84.2
# st_avg_spin             243.927852    2003.0     2356.0    2533.0     2714.0
# st_avg_break_x           10.569491     -17.4       10.0      12.5       14.9
# st_avg_break_z            4.650475     -53.4      -43.2     -40.3      -37.8
#
#                             max
# last_name, first_name       NaN
# player_id              808967.0
# year                     2025.0
# p_formatted_ip            208.2
# pa                        856.0
# ...                         ...
# kn_avg_break_z            -43.3
# st_avg_speed               88.1
# st_avg_spin              3182.0
# st_avg_break_x             19.5
# st_avg_break_z            -26.3
#
# [87 rows x 11 columns]
#
# ============================================================
#
# UNIQUE VALUE COUNTS AND PERCENTS:
#
#                        unique_count  percent_unique
# last_name, first_name         152.0       71.028037
# player_id                     152.0       71.028037
# year                            2.0        0.934579
# p_formatted_ip                141.0       65.887850
# pa                            156.0       72.897196
# ...                             ...             ...
# kn_avg_break_z                  3.0        1.401869
# st_avg_speed                   60.0       28.037383
# st_avg_spin                    95.0       44.392523
# st_avg_break_x                 72.0       33.644860
# st_avg_break_z                 79.0       36.915888
#
# [87 rows x 2 columns]
#
# ============================================================
#
# RANGES OF VALUES (NUMERIC COLUMNS):
#
#                      min       max     range
# player_id       434378.0  808967.0  374589.0
# year              2024.0    2025.0       1.0
# p_formatted_ip     111.0     208.2      97.2
# pa                 503.0     856.0     353.0
# hit                 92.0     210.0     118.0
# ...                  ...       ...       ...
# kn_avg_break_z     -49.6     -43.3       6.3
# st_avg_speed        72.6      88.1      15.5
# st_avg_spin       2003.0    3182.0    1179.0
# st_avg_break_x     -17.4      19.5      36.9
# st_avg_break_z     -53.4     -26.3      27.1
#
# [86 rows x 3 columns]
#
# ============================================================

# %%
# ==========================================
# 1. CHECK FOR MISSING VALUES
# ==========================================

print("TOTAL MISSING VALUES IN DATAFRAME:")
print(df1.isnull().sum())
print("\n" + "="*60 + "\n")

print("ANY NULLS PRESENT?:", df1.isnull().values.any())
print("\n" + "="*60 + "\n")

# OPTIONAL: View rows with ANY missing values
missing_rows = df1[df1.isnull().any(axis=1)]
print("ROWS WITH MISSING VALUES:")
print(missing_rows.head())
print("\n" + "="*60 + "\n")

# ==========================================
# 2. CHECK FOR DUPLICATES
# ==========================================

print("NUMBER OF DUPLICATE ROWS:", df1.duplicated().sum())
print("\n" + "="*60 + "\n")

# OPTIONAL: View duplicate rows
duplicate_rows = df1[df1.duplicated(keep=False)]
print("DUPLICATE ROW EXAMPLES:")
print(duplicate_rows.head())
print("\n" + "="*60 + "\n")
# Out:
# TOTAL MISSING VALUES IN DATAFRAME:
# last_name, first_name      0
# player_id                  0
# year                       0
# p_formatted_ip             0
# pa                         0
#                         ...
# kn_avg_break_z           212
# st_avg_speed             113
# st_avg_spin              113
# st_avg_break_x           113
# st_avg_break_z           113
# Length: 87, dtype: int64
#
# ============================================================
#
# ANY NULLS PRESENT?: True
#
# ============================================================
#
# ROWS WITH MISSING VALUES:
#   last_name, first_name  player_id  year  p_formatted_ip   pa  hit  home_run  \
# 0      Parker, Mitchell     680730  2025           164.2  725  178        25
# 1       Hendricks, Kyle     543294  2025           164.2  695  167        25
# 2            Lugo, Seth     607625  2024           206.2  836  177        16
# 3   Arrighetti, Spencer     681293  2024           145.0  632  139        21
# 4            Woo, Bryan     693433  2025           186.2  731  137        26
#
#    strikeout  k_percent  bb_percent  ...  fs_avg_break_z  n_kn_formatted  \
# 0        103       14.2         8.0  ...           -28.5             NaN
# 1        114       16.4         6.2  ...             NaN             NaN
# 2        181       21.7         5.7  ...           -32.4             NaN
# 3        171       27.1        10.3  ...             NaN             NaN
# 4        198       27.1         4.9  ...             NaN             NaN
#
#    kn_avg_speed  kn_avg_spin  kn_avg_break_x  kn_avg_break_z  st_avg_speed  \
# 0           NaN          NaN             NaN             NaN           NaN
# 1           NaN          NaN             NaN             NaN           NaN
# 2           NaN          NaN             NaN             NaN          82.1
# 3           NaN          NaN             NaN             NaN          80.8
# 4           NaN          NaN             NaN             NaN          85.1
#
#    st_avg_spin  st_avg_break_x  st_avg_break_z
# 0          NaN             NaN             NaN
# 1          NaN             NaN             NaN
# 2       2843.0            13.5           -37.9
# 3       2800.0            14.7           -40.5
# 4       2485.0            10.6           -34.0
#
# [5 rows x 87 columns]
#
# ============================================================
#
# NUMBER OF DUPLICATE ROWS: 0
#
# ============================================================
#
# DUPLICATE ROW EXAMPLES:
# Empty DataFrame
# Columns: [last_name, first_name, player_id, year, p_formatted_ip, pa, hit, home_run, strikeout, k_percent, bb_percent, batting_avg, slg_percent, on_base_percent, on_base_plus_slg, p_earned_run, p_run, p_out, p_win, p_loss, p_era, p_lob, p_rbi, p_ab_scoring, p_called_strike, p_swinging_strike, p_total_ball, p_total_strike, p_total_swinging_strike, p_inh_runner, xba, xslg, woba, xwoba, xobp, sweet_spot_percent, barrel_batted_rate, solidcontact_percent, hard_hit_percent, avg_best_speed, avg_hyper_speed, whiff_percent, swing_percent, n_ff_formatted, ff_avg_speed, ff_avg_spin, ff_avg_break_x, ff_avg_break_z, ff_range_speed, n_sl_formatted, sl_avg_speed, sl_avg_spin, sl_avg_break_x, sl_avg_break_z, n_ch_formatted, ch_avg_speed, ch_avg_spin, ch_avg_break_x, ch_avg_break_z, n_cu_formatted, cu_avg_speed, cu_avg_spin, cu_avg_break_x, cu_avg_break_z, n_si_formatted, si_avg_speed, si_avg_spin, si_avg_break_x, si_avg_break_z, n_fc_formatted, fc_avg_speed, fc_avg_spin, fc_avg_break_x, fc_avg_break_z, n_fs_formatted, fs_avg_speed, fs_avg_spin, fs_avg_break_x, fs_avg_break_z, n_kn_formatted, kn_avg_speed, kn_avg_spin, kn_avg_break_x, kn_avg_break_z, st_avg_speed, st_avg_spin, st_avg_break_x, st_avg_break_z]
# Index: []
#
# [0 rows x 87 columns]
#
# ============================================================

# %%
# ==========================================
# 1. Identify pitch-type columns
#    Any column starting with these prefixes:
#    n_  = count of pitches thrown
#    ff_, sl_, ch_, cu_, si_, fc_, fs_, kn_, st_
# ==========================================

count_cols = [col for col in df1.columns if col.startswith("n_")]

metric_cols = [col for col in df1.columns 
               if any(col.startswith(prefix) for prefix in 
                      ["ff_", "sl_", "ch_", "cu_", "si_", "fc_", "fs_", "kn_", "st_"])
               and not col.startswith("n_")]

print("COUNT COLUMNS (pitch counts):", count_cols)
print("METRIC COLUMNS (pitch metrics):", metric_cols)

# ==========================================
# 2. CLEAN COUNT COLUMNS
#    Replace NaN with 0 → means no pitches of that type thrown
# ==========================================

df1[count_cols] = df1[count_cols].fillna(0)

# ==========================================
# 3. CLEAN METRIC COLUMNS
#    Two options — choose ONE
# ==========================================

# Replace NaN with 0 (best for ML) ----
df1[metric_cols] = df1[metric_cols].fillna(0)

# ==========================================
# 4. Final checks
# ==========================================

print("ANY NULLS LEFT?:", df1.isnull().values.any())

missing_summary = df1.isnull().sum()
print("\nMISSING VALUES AFTER CLEANING:")
print(missing_summary[missing_summary > 0])
# Out:
# COUNT COLUMNS (pitch counts): ['n_ff_formatted', 'n_sl_formatted', 'n_ch_formatted', 'n_cu_formatted', 'n_si_formatted', 'n_fc_formatted', 'n_fs_formatted', 'n_kn_formatted']
# METRIC COLUMNS (pitch metrics): ['ff_avg_speed', 'ff_avg_spin', 'ff_avg_break_x', 'ff_avg_break_z', 'ff_range_speed', 'sl_avg_speed', 'sl_avg_spin', 'sl_avg_break_x', 'sl_avg_break_z', 'ch_avg_speed', 'ch_avg_spin', 'ch_avg_break_x', 'ch_avg_break_z', 'cu_avg_speed', 'cu_avg_spin', 'cu_avg_break_x', 'cu_avg_break_z', 'si_avg_speed', 'si_avg_spin', 'si_avg_break_x', 'si_avg_break_z', 'fc_avg_speed', 'fc_avg_spin', 'fc_avg_break_x', 'fc_avg_break_z', 'fs_avg_speed', 'fs_avg_spin', 'fs_avg_break_x', 'fs_avg_break_z', 'kn_avg_speed', 'kn_avg_spin', 'kn_avg_break_x', 'kn_avg_break_z', 'st_avg_speed', 'st_avg_spin', 'st_avg_break_x', 'st_avg_break_z']
# ANY NULLS LEFT?: False
#
# MISSING VALUES AFTER CLEANING:
# Series([], dtype: int64)

# %%
# ==========================================
# STANDARDIZE COLUMN NAMES
# ==========================================

# The goal here is to make all column names:
# - lowercase
# - consistent
# - punctuation-free
# - Python-friendly (snake_case)
# - easy to reference in later steps

# Example:
# "Last_Name, First_Name" → "last_name_first_name"
# "SI Avg Speed" → "si_avg_speed"

# --- Save the original column names (optional but helpful for comparison) ---
original_cols = df1.columns.tolist()

# --- Apply standardized formatting ---
df1.columns = (
    df1.columns
    .str.lower()                              # convert to lowercase
    .str.replace("[^a-z0-9]+", "_", regex=True)  # replace punctuation/spaces with underscores
    .str.strip("_")                           # remove extra underscores at start/end
)

# --- Show comparison before and after ---
print("BEFORE STANDARDIZATION:")
print(original_cols)

print("\nAFTER STANDARDIZATION:")
print(df1.columns.tolist())
# Out:
# BEFORE STANDARDIZATION:
# ['last_name, first_name', 'player_id', 'year', 'p_formatted_ip', 'pa', 'hit', 'home_run', 'strikeout', 'k_percent', 'bb_percent', 'batting_avg', 'slg_percent', 'on_base_percent', 'on_base_plus_slg', 'p_earned_run', 'p_run', 'p_out', 'p_win', 'p_loss', 'p_era', 'p_lob', 'p_rbi', 'p_ab_scoring', 'p_called_strike', 'p_swinging_strike', 'p_total_ball', 'p_total_strike', 'p_total_swinging_strike', 'p_inh_runner', 'xba', 'xslg', 'woba', 'xwoba', 'xobp', 'sweet_spot_percent', 'barrel_batted_rate', 'solidcontact_percent', 'hard_hit_percent', 'avg_best_speed', 'avg_hyper_speed', 'whiff_percent', 'swing_percent', 'n_ff_formatted', 'ff_avg_speed', 'ff_avg_spin', 'ff_avg_break_x', 'ff_avg_break_z', 'ff_range_speed', 'n_sl_formatted', 'sl_avg_speed', 'sl_avg_spin', 'sl_avg_break_x', 'sl_avg_break_z', 'n_ch_formatted', 'ch_avg_speed', 'ch_avg_spin', 'ch_avg_break_x', 'ch_avg_break_z', 'n_cu_formatted', 'cu_avg_speed', 'cu_avg_spin', 'cu_avg_break_x', 'cu_avg_break_z', 'n_si_formatted', 'si_avg_speed', 'si_avg_spin', 'si_avg_break_x', 'si_avg_break_z', 'n_fc_formatted', 'fc_avg_speed', 'fc_avg_spin', 'fc_avg_break_x', 'fc_avg_break_z', 'n_fs_formatted', 'fs_avg_speed', 'fs_avg_spin', 'fs_avg_break_x', 'fs_avg_break_z', 'n_kn_formatted', 'kn_avg_speed', 'kn_avg_spin', 'kn_avg_break_x', 'kn_avg_break_z', 'st_avg_speed', 'st_avg_spin', 'st_avg_break_x', 'st_avg_break_z']
#
# AFTER STANDARDIZATION:
# ['last_name_first_name', 'player_id', 'year', 'p_formatted_ip', 'pa', 'hit', 'home_run', 'strikeout', 'k_percent', 'bb_percent', 'batting_avg', 'slg_percent', 'on_base_percent', 'on_base_plus_slg', 'p_earned_run', 'p_run', 'p_out', 'p_win', 'p_loss', 'p_era', 'p_lob', 'p_rbi', 'p_ab_scoring', 'p_called_strike', 'p_swinging_strike', 'p_total_ball', 'p_total_strike', 'p_total_swinging_strike', 'p_inh_runner', 'xba', 'xslg', 'woba', 'xwoba', 'xobp', 'sweet_spot_percent', 'barrel_batted_rate', 'solidcontact_percent', 'hard_hit_percent', 'avg_best_speed', 'avg_hyper_speed', 'whiff_percent', 'swing_percent', 'n_ff_formatted', 'ff_avg_speed', 'ff_avg_spin', 'ff_avg_break_x', 'ff_avg_break_z', 'ff_range_speed', 'n_sl_formatted', 'sl_avg_speed', 'sl_avg_spin', 'sl_avg_break_x', 'sl_avg_break_z', 'n_ch_formatted', 'ch_avg_speed', 'ch_avg_spin', 'ch_avg_break_x', 'ch_avg_break_z', 'n_cu_formatted', 'cu_avg_speed', 'cu_avg_spin', 'cu_avg_break_x', 'cu_avg_break_z', 'n_si_formatted', 'si_avg_speed', 'si_avg_spin', 'si_avg_break_x', 'si_avg_break_z', 'n_fc_formatted', 'fc_avg_speed', 'fc_avg_spin', 'fc_avg_break_x', 'fc_avg_break_z', 'n_fs_formatted', 'fs_avg_speed', 'fs_avg_spin', 'fs_avg_break_x', 'fs_avg_break_z', 'n_kn_formatted', 'kn_avg_speed', 'kn_avg_spin', 'kn_avg_break_x', 'kn_avg_break_z', 'st_avg_speed', 'st_avg_spin', 'st_avg_break_x', 'st_avg_break_z']

# %%
#Load 2nd Dataset
df2 = pd.read_csv("stats (5).csv")

# ==========================================
# Display the first few rows to verify load
# ==========================================
df2.head()
# Out:
#   last_name, first_name  player_id  year   pa  hit  home_run  strikeout  walk  \
# 0     De La Cruz, Bryan     650559  2024  622  136        21        170    29
# 1     Castellanos, Nick     592206  2024  659  154        23        139    41
# 2    Morel, Christopher     666624  2024  611  105        21        159    61
# 3          Thomas, Lane     657041  2024  528  112        15        137    44
# 4         Bregman, Alex     608324  2024  634  151        26         86    44
#
#    k_percent  bb_percent  ...  oz_swing_percent  oz_swing_miss_percent  \
# 0       27.3         4.7  ...              32.6                   47.0
# 1       21.1         6.2  ...              37.8                   51.9
# 2       26.0        10.0  ...              26.2                   51.1
# 3       25.9         8.3  ...              22.9                   40.9
# 4       13.6         6.9  ...              23.6                   24.7
#
#    oz_contact_percent  out_zone_swing_miss  out_zone_swing  \
# 0                53.0                  188             400
# 1                48.1                  234             451
# 2                48.9                  161             315
# 3                59.1                   96             235
# 4                75.3                   69             279
#
#    iz_contact_percent  in_zone_swing_miss  in_zone_swing  whiff_percent  \
# 0                77.6                 197            879           30.1
# 1                80.6                 176            909           30.1
# 2                72.7                 216            790           34.1
# 3                82.8                 116            675           23.3
# 4                91.3                  69            796           12.8
#
#    swing_percent
# 0           53.4
# 1           58.0
# 2           47.0
# 3           43.8
# 4           44.9
#
# [5 rows x 44 columns]

# %%
# FOR Data Set 2

# ==========================================
# 1. Column Names
# ==========================================
print("COLUMN NAMES (df2):")
print(df2.columns.tolist())
print("\n" + "="*60 + "\n")

# ==========================================
# 2. Data Types
# ==========================================
print("DATA TYPES (df2):")
print(df2.dtypes)
print("\n" + "="*60 + "\n")

# ==========================================
# 3. Column Descriptions (summary statistics)
#    Works for both numeric & categorical features
# ==========================================
print("SUMMARY STATISTICS (df2):")
print(df2.describe(include='all').transpose())
print("\n" + "="*60 + "\n")

# ==========================================
# 4. Unique Values (counts + percentages)
# ==========================================
print("UNIQUE VALUE COUNTS AND PERCENTS (df2):\n")
unique_summary_df2 = {}

for col in df2.columns:
    unique_count = df2[col].nunique(dropna=False)
    percent_unique = (unique_count / len(df2)) * 100
    
    unique_summary_df2[col] = {
        "unique_count": unique_count,
        "percent_unique": percent_unique
    }

unique_df2 = pd.DataFrame(unique_summary_df2).transpose()
print(unique_df2)
print("\n" + "="*60 + "\n")

# ==========================================
# 5. Value Ranges (for numeric columns)
# ==========================================
print("RANGES OF VALUES (NUMERIC COLUMNS FOR df2):\n")
numeric_cols_df2 = df2.select_dtypes(include=[np.number]).columns

range_summary_df2 = pd.DataFrame({
    "min": df2[numeric_cols_df2].min(),
    "max": df2[numeric_cols_df2].max(),
    "range": df2[numeric_cols_df2].max() - df2[numeric_cols_df2].min()
})

print(range_summary_df2)
print("\n" + "="*60 + "\n")

# ==========================================
# Done — dataset overview for df2 complete
# ==========================================
# Out:
# COLUMN NAMES (df2):
# ['last_name, first_name', 'player_id', 'year', 'pa', 'hit', 'home_run', 'strikeout', 'walk', 'k_percent', 'bb_percent', 'batting_avg', 'slg_percent', 'on_base_percent', 'on_base_plus_slg', 'b_rbi', 'r_total_stolen_base', 'b_ball', 'b_foul', 'b_total_strike', 'b_total_swinging_strike', 'xslg', 'woba', 'xwoba', 'xobp', 'avg_swing_speed', 'blasts_contact', 'exit_velocity_avg', 'sweet_spot_percent', 'barrel_batted_rate', 'hard_hit_percent', 'avg_best_speed', 'avg_hyper_speed', 'z_swing_percent', 'z_swing_miss_percent', 'oz_swing_percent', 'oz_swing_miss_percent', 'oz_contact_percent', 'out_zone_swing_miss', 'out_zone_swing', 'iz_contact_percent', 'in_zone_swing_miss', 'in_zone_swing', 'whiff_percent', 'swing_percent']
#
# ============================================================
#
# DATA TYPES (df2):
# last_name, first_name       object
# player_id                    int64
# year                         int64
# pa                           int64
# hit                          int64
# home_run                     int64
# strikeout                    int64
# walk                         int64
# k_percent                  float64
# bb_percent                 float64
# batting_avg                float64
# slg_percent                float64
# on_base_percent            float64
# on_base_plus_slg           float64
# b_rbi                        int64
# r_total_stolen_base          int64
# b_ball                       int64
# b_foul                       int64
# b_total_strike               int64
# b_total_swinging_strike      int64
# xslg                       float64
# woba                       float64
# xwoba                      float64
# xobp                       float64
# avg_swing_speed            float64
# blasts_contact             float64
# exit_velocity_avg          float64
# sweet_spot_percent         float64
# barrel_batted_rate         float64
# hard_hit_percent           float64
# avg_best_speed             float64
# avg_hyper_speed            float64
# z_swing_percent            float64
# z_swing_miss_percent       float64
# oz_swing_percent           float64
# oz_swing_miss_percent      float64
# oz_contact_percent         float64
# out_zone_swing_miss          int64
# out_zone_swing               int64
# iz_contact_percent         float64
# in_zone_swing_miss           int64
# in_zone_swing                int64
# whiff_percent              float64
# swing_percent              float64
# dtype: object
#
# ============================================================
#
# SUMMARY STATISTICS (df2):
#                          count unique                top freq           mean  \
# last_name, first_name      273    185  Castellanos, Nick    2            NaN
# player_id                273.0    NaN                NaN  NaN  647609.754579
# year                     273.0    NaN                NaN  NaN    2024.527473
# pa                       273.0    NaN                NaN  NaN     608.666667
# hit                      273.0    NaN                NaN  NaN     140.578755
# home_run                 273.0    NaN                NaN  NaN      21.772894
# strikeout                273.0    NaN                NaN  NaN     126.098901
# walk                     273.0    NaN                NaN  NaN      53.956044
# k_percent                273.0    NaN                NaN  NaN      20.712821
# bb_percent               273.0    NaN                NaN  NaN       8.792308
# batting_avg              273.0    NaN                NaN  NaN       0.258366
# slg_percent              273.0    NaN                NaN  NaN       0.436308
# on_base_percent          273.0    NaN                NaN  NaN        0.32959
# on_base_plus_slg         273.0    NaN                NaN  NaN       0.765897
# b_rbi                    273.0    NaN                NaN  NaN      74.754579
# r_total_stolen_base      273.0    NaN                NaN  NaN      12.659341
# b_ball                   273.0    NaN                NaN  NaN     804.912088
# b_foul                   273.0    NaN                NaN  NaN     426.886447
# b_total_strike           273.0    NaN                NaN  NaN    1506.747253
# b_total_swinging_strike  273.0    NaN                NaN  NaN      235.78022
# xslg                     273.0    NaN                NaN  NaN         0.4323
# woba                     273.0    NaN                NaN  NaN       0.331125
# xwoba                    273.0    NaN                NaN  NaN       0.332223
# xobp                     273.0    NaN                NaN  NaN       0.329875
# avg_swing_speed          273.0    NaN                NaN  NaN      72.003663
# blasts_contact           273.0    NaN                NaN  NaN      15.524908
# exit_velocity_avg        273.0    NaN                NaN  NaN       89.89707
# sweet_spot_percent       273.0    NaN                NaN  NaN      34.652747
# barrel_batted_rate       273.0    NaN                NaN  NaN       9.531136
# hard_hit_percent         273.0    NaN                NaN  NaN      42.562271
# avg_best_speed           273.0    NaN                NaN  NaN     100.746523
# avg_hyper_speed          273.0    NaN                NaN  NaN      94.728536
# z_swing_percent          273.0    NaN                NaN  NaN       67.40696
# z_swing_miss_percent     273.0    NaN                NaN  NaN      16.186447
# oz_swing_percent         273.0    NaN                NaN  NaN       28.01978
# oz_swing_miss_percent    273.0    NaN                NaN  NaN      42.459341
# oz_contact_percent       273.0    NaN                NaN  NaN      57.538828
# out_zone_swing_miss      273.0    NaN                NaN  NaN     141.908425
# out_zone_swing           273.0    NaN                NaN  NaN     332.410256
# iz_contact_percent       273.0    NaN                NaN  NaN      83.810256
# in_zone_swing_miss       273.0    NaN                NaN  NaN     129.791209
# in_zone_swing            273.0    NaN                NaN  NaN     790.714286
# whiff_percent            273.0    NaN                NaN  NaN      23.922711
# swing_percent            273.0    NaN                NaN  NaN      47.604762
#
#                                  std        min        25%         50%  \
# last_name, first_name            NaN        NaN        NaN         NaN
# player_id                51704.71239   457705.0   623993.0    665161.0
# year                        0.500162     2024.0     2024.0      2025.0
# pa                         62.243198      503.0      553.0       609.0
# hit                        21.431196       94.0      124.0       139.0
# home_run                    9.847723        2.0       15.0        20.0
# strikeout                  36.399556       21.0      100.0       125.0
# walk                       20.206605       15.0       40.0        52.0
# k_percent                   5.507543        3.1       16.8        20.8
# bb_percent                  2.879194        2.5        6.7         8.6
# batting_avg                 0.023802      0.196      0.242       0.257
# slg_percent                 0.060851      0.306      0.394       0.431
# on_base_percent              0.02972      0.268      0.312       0.327
# on_base_plus_slg            0.082463      0.593      0.716       0.757
# b_rbi                      19.357754       23.0       61.0        74.0
# r_total_stolen_base        11.633073        0.0        3.0         9.0
# b_ball                      141.1874      506.0      694.0       791.0
# b_foul                     69.494326      259.0      379.0       418.0
# b_total_strike            166.418983     1166.0     1373.0      1503.0
# b_total_swinging_strike    78.602565       46.0      180.0       236.0
# xslg                        0.065052      0.304       0.39       0.423
# woba                        0.031172      0.263      0.313       0.328
# xwoba                       0.032256      0.261      0.313       0.328
# xobp                        0.028893      0.259      0.311       0.326
# avg_swing_speed             2.710041       62.6       70.6        72.2
# blasts_contact              4.455355        2.2       12.7        15.6
# exit_velocity_avg           2.205122       83.4       88.5        89.9
# sweet_spot_percent          3.247963       26.2       32.6        34.5
# barrel_batted_rate          4.349647        0.8        6.7         9.1
# hard_hit_percent            7.644039       16.7       38.2        43.4
# avg_best_speed              2.545929  93.590259  99.170989  100.814056
# avg_hyper_speed             1.518321  90.800701  93.738512   94.773964
# z_swing_percent             5.708468       52.8       63.8        67.2
# z_swing_miss_percent        4.863247        3.9       13.0        16.2
# oz_swing_percent            5.732356       15.9       23.9        27.0
# oz_swing_miss_percent        9.78393        7.7       36.6        42.9
# oz_contact_percent          9.782448       37.2       50.2        57.1
# out_zone_swing_miss         47.47355       30.0      105.0       140.0
# out_zone_swing             73.998163      181.0      277.0       327.0
# iz_contact_percent          4.863479       71.4       80.6        83.8
# in_zone_swing_miss         47.561844       28.0       94.0       127.0
# in_zone_swing             102.677066      576.0      714.0       786.0
# whiff_percent               5.982622        5.3       20.2        24.4
# swing_percent               4.750814       35.5       44.5        47.4
#
#                                 75%         max
# last_name, first_name           NaN         NaN
# player_id                  678246.0    808982.0
# year                         2025.0      2025.0
# pa                            655.0       735.0
# hit                           155.0       211.0
# home_run                       27.0        60.0
# strikeout                     153.0       221.0
# walk                           65.0       133.0
# k_percent                      25.2        34.4
# bb_percent                     10.8        18.9
# batting_avg                   0.273       0.332
# slg_percent                   0.469       0.701
# on_base_percent               0.346       0.458
# on_base_plus_slg              0.804       1.159
# b_rbi                          86.0       144.0
# r_total_stolen_base            19.0        67.0
# b_ball                        894.0      1200.0
# b_foul                        474.0       644.0
# b_total_strike               1636.0      1912.0
# b_total_swinging_strike       294.0       457.0
# xslg                          0.461       0.722
# woba                          0.347       0.476
# xwoba                         0.346       0.479
# xobp                          0.344       0.449
# avg_swing_speed                73.8        78.8
# blasts_contact                 18.3        26.3
# exit_velocity_avg              91.2        96.2
# sweet_spot_percent             36.7        44.4
# barrel_batted_rate             12.3        26.9
# hard_hit_percent               47.4        61.0
# avg_best_speed           102.515756  107.307979
# avg_hyper_speed           95.682678   99.103702
# z_swing_percent                71.3        82.0
# z_swing_miss_percent           19.4        28.6
# oz_swing_percent               31.7        46.4
# oz_swing_miss_percent          49.8        62.8
# oz_contact_percent             63.4        92.3
# out_zone_swing_miss           175.0       310.0
# out_zone_swing                387.0       579.0
# iz_contact_percent             87.0        96.1
# in_zone_swing_miss            158.0       299.0
# in_zone_swing                 866.0      1044.0
# whiff_percent                  28.9        36.4
# swing_percent                  50.4        62.3
#
# ============================================================
#
# UNIQUE VALUE COUNTS AND PERCENTS (df2):
#
#                          unique_count  percent_unique
# last_name, first_name           185.0       67.765568
# player_id                       185.0       67.765568
# year                              2.0        0.732601
# pa                              159.0       58.241758
# hit                              88.0       32.234432
# home_run                         48.0       17.582418
# strikeout                       121.0       44.322344
# walk                             78.0       28.571429
# k_percent                       139.0       50.915751
# bb_percent                      106.0       38.827839
# batting_avg                      90.0       32.967033
# slg_percent                     161.0       58.974359
# on_base_percent                 102.0       37.362637
# on_base_plus_slg                174.0       63.736264
# b_rbi                            79.0       28.937729
# r_total_stolen_base              45.0       16.483516
# b_ball                          214.0       78.388278
# b_foul                          177.0       64.835165
# b_total_strike                  227.0       83.150183
# b_total_swinging_strike         175.0       64.102564
# xslg                            153.0       56.043956
# woba                            105.0       38.461538
# xwoba                           106.0       38.827839
# xobp                            103.0       37.728938
# avg_swing_speed                  96.0       35.164835
# blasts_contact                  140.0       51.282051
# exit_velocity_avg                88.0       32.234432
# sweet_spot_percent              116.0       42.490842
# barrel_batted_rate              134.0       49.084249
# hard_hit_percent                181.0       66.300366
# avg_best_speed                  273.0      100.000000
# avg_hyper_speed                 273.0      100.000000
# z_swing_percent                 152.0       55.677656
# z_swing_miss_percent            147.0       53.846154
# oz_swing_percent                160.0       58.608059
# oz_swing_miss_percent           186.0       68.131868
# oz_contact_percent              186.0       68.131868
# out_zone_swing_miss             135.0       49.450549
# out_zone_swing                  171.0       62.637363
# iz_contact_percent              148.0       54.212454
# in_zone_swing_miss              139.0       50.915751
# in_zone_swing                   206.0       75.457875
# whiff_percent                   161.0       58.974359
# swing_percent                   145.0       53.113553
#
# ============================================================
#
# RANGES OF VALUES (NUMERIC COLUMNS FOR df2):
#
#                                    min            max          range
# player_id                457705.000000  808982.000000  351277.000000
# year                       2024.000000    2025.000000       1.000000
# pa                          503.000000     735.000000     232.000000
# hit                          94.000000     211.000000     117.000000
# home_run                      2.000000      60.000000      58.000000
# strikeout                    21.000000     221.000000     200.000000
# walk                         15.000000     133.000000     118.000000
# k_percent                     3.100000      34.400000      31.300000
# bb_percent                    2.500000      18.900000      16.400000
# batting_avg                   0.196000       0.332000       0.136000
# slg_percent                   0.306000       0.701000       0.395000
# on_base_percent               0.268000       0.458000       0.190000
# on_base_plus_slg              0.593000       1.159000       0.566000
# b_rbi                        23.000000     144.000000     121.000000
# r_total_stolen_base           0.000000      67.000000      67.000000
# b_ball                      506.000000    1200.000000     694.000000
# b_foul                      259.000000     644.000000     385.000000
# b_total_strike             1166.000000    1912.000000     746.000000
# b_total_swinging_strike      46.000000     457.000000     411.000000
# xslg                          0.304000       0.722000       0.418000
# woba                          0.263000       0.476000       0.213000
# xwoba                         0.261000       0.479000       0.218000
# xobp                          0.259000       0.449000       0.190000
# avg_swing_speed              62.600000      78.800000      16.200000
# blasts_contact                2.200000      26.300000      24.100000
# exit_velocity_avg            83.400000      96.200000      12.800000
# sweet_spot_percent           26.200000      44.400000      18.200000
# barrel_batted_rate            0.800000      26.900000      26.100000
# hard_hit_percent             16.700000      61.000000      44.300000
# avg_best_speed               93.590259     107.307979      13.717719
# avg_hyper_speed              90.800701      99.103702       8.303000
# z_swing_percent              52.800000      82.000000      29.200000
# z_swing_miss_percent          3.900000      28.600000      24.700000
# oz_swing_percent             15.900000      46.400000      30.500000
# oz_swing_miss_percent         7.700000      62.800000      55.100000
# oz_contact_percent           37.200000      92.300000      55.100000
# out_zone_swing_miss          30.000000     310.000000     280.000000
# out_zone_swing              181.000000     579.000000     398.000000
# iz_contact_percent           71.400000      96.100000      24.700000
# in_zone_swing_miss           28.000000     299.000000     271.000000
# in_zone_swing               576.000000    1044.000000     468.000000
# whiff_percent                 5.300000      36.400000      31.100000
# swing_percent                35.500000      62.300000      26.800000
#
# ============================================================

# %%
# ==========================================
# 1. CHECK FOR MISSING VALUES (df2)
# ==========================================

print("TOTAL MISSING VALUES IN DATAFRAME (df2):")
print(df2.isnull().sum())
print("\n" + "="*60 + "\n")

print("ANY NULLS PRESENT IN df2?:", df2.isnull().values.any())
print("\n" + "="*60 + "\n")

# OPTIONAL: View rows with ANY missing values
missing_rows_df2 = df2[df2.isnull().any(axis=1)]
print("ROWS WITH MISSING VALUES IN df2:")
print(missing_rows_df2.head())
print("\n" + "="*60 + "\n")

# ==========================================
# 2. CHECK FOR DUPLICATES (df2)
# ==========================================

print("NUMBER OF DUPLICATE ROWS IN df2:", df2.duplicated().sum())
print("\n" + "="*60 + "\n")

# OPTIONAL: View duplicate rows
duplicate_rows_df2 = df2[df2.duplicated(keep=False)]
print("DUPLICATE ROW EXAMPLES FROM df2:")
print(duplicate_rows_df2.head())
print("\n" + "="*60 + "\n")
# Out:
# TOTAL MISSING VALUES IN DATAFRAME (df2):
# last_name, first_name      0
# player_id                  0
# year                       0
# pa                         0
# hit                        0
# home_run                   0
# strikeout                  0
# walk                       0
# k_percent                  0
# bb_percent                 0
# batting_avg                0
# slg_percent                0
# on_base_percent            0
# on_base_plus_slg           0
# b_rbi                      0
# r_total_stolen_base        0
# b_ball                     0
# b_foul                     0
# b_total_strike             0
# b_total_swinging_strike    0
# xslg                       0
# woba                       0
# xwoba                      0
# xobp                       0
# avg_swing_speed            0
# blasts_contact             0
# exit_velocity_avg          0
# sweet_spot_percent         0
# barrel_batted_rate         0
# hard_hit_percent           0
# avg_best_speed             0
# avg_hyper_speed            0
# z_swing_percent            0
# z_swing_miss_percent       0
# oz_swing_percent           0
# oz_swing_miss_percent      0
# oz_contact_percent         0
# out_zone_swing_miss        0
# out_zone_swing             0
# iz_contact_percent         0
# in_zone_swing_miss         0
# in_zone_swing              0
# whiff_percent              0
# swing_percent              0
# dtype: int64
#
# ============================================================
#
# ANY NULLS PRESENT IN df2?: False
#
# ============================================================
#
# ROWS WITH MISSING VALUES IN df2:
# Empty DataFrame
# Columns: [last_name, first_name, player_id, year, pa, hit, home_run, strikeout, walk, k_percent, bb_percent, batting_avg, slg_percent, on_base_percent, on_base_plus_slg, b_rbi, r_total_stolen_base, b_ball, b_foul, b_total_strike, b_total_swinging_strike, xslg, woba, xwoba, xobp, avg_swing_speed, blasts_contact, exit_velocity_avg, sweet_spot_percent, barrel_batted_rate, hard_hit_percent, avg_best_speed, avg_hyper_speed, z_swing_percent, z_swing_miss_percent, oz_swing_percent, oz_swing_miss_percent, oz_contact_percent, out_zone_swing_miss, out_zone_swing, iz_contact_percent, in_zone_swing_miss, in_zone_swing, whiff_percent, swing_percent]
# Index: []
#
# [0 rows x 44 columns]
#
# ============================================================
#
# NUMBER OF DUPLICATE ROWS IN df2: 0
#
# ============================================================
#
# DUPLICATE ROW EXAMPLES FROM df2:
# Empty DataFrame
# Columns: [last_name, first_name, player_id, year, pa, hit, home_run, strikeout, walk, k_percent, bb_percent, batting_avg, slg_percent, on_base_percent, on_base_plus_slg, b_rbi, r_total_stolen_base, b_ball, b_foul, b_total_strike, b_total_swinging_strike, xslg, woba, xwoba, xobp, avg_swing_speed, blasts_contact, exit_velocity_avg, sweet_spot_percent, barrel_batted_rate, hard_hit_percent, avg_best_speed, avg_hyper_speed, z_swing_percent, z_swing_miss_percent, oz_swing_percent, oz_swing_miss_percent, oz_contact_percent, out_zone_swing_miss, out_zone_swing, iz_contact_percent, in_zone_swing_miss, in_zone_swing, whiff_percent, swing_percent]
# Index: []
#
# [0 rows x 44 columns]
#
# ============================================================

# %%
#THIS MARKS WHERE CAPSTONE TWO STEP 3 STARTS
#THIS MARKS WHERE CAPSTONE TWO STEP 3 STARTS
#THIS MARKS WHERE CAPSTONE TWO STEP 3 STARTS

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Set visual style
sns.set_theme(style="whitegrid")
# %matplotlib inline

# Reminder of our DataFrames:
# df1: Pitching Data (stats (4).csv)
# df2: Batting Data (stats (5).csv)

print(f"Pitching Dataset Shape: {df1.shape}")
print(f"Batting Dataset Shape: {df2.shape}")
# Out:
# Pitching Dataset Shape: (214, 87)
# Batting Dataset Shape: (273, 44)

# %%
# ============================================================
# ANALYSIS: Batting Relationships (Independent vs Dependent)
# ============================================================

# Selecting the key features from your proposal
batter_features = ['barrel_batted_rate', 'hard_hit_percent', 'exit_velocity_avg', 
                   'avg_swing_speed', 'sweet_spot_percent', 'xwoba']

# Create a Correlation Matrix for Batters
plt.figure(figsize=(10, 8))
corr_matrix_bat = df2[batter_features].corr()
sns.heatmap(corr_matrix_bat, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix: Batted Ball Quality vs. xwOBA')
plt.show()

# VISUALIZATION: Scatter plot of Barrel% vs xwOBA (High ROI Predictor)
plt.figure(figsize=(8, 6))
sns.regplot(data=df2, x='barrel_batted_rate', y='xwoba', scatter_kws={'alpha':0.5}, line_kws={'color':'red'})
plt.title('Impact of Barrel % on Expected Weighted On-Base Average (xwOBA)')
plt.xlabel('Barrel %')
plt.ylabel('xwOBA')
plt.show()

# %%
# ============================================================
# ANALYSIS: Pitching - Velocity vs. Strikeout Rate
# ============================================================

# Let's look at Fastball Velocity (ff_avg_speed) vs Strikeout Rate (k_percent)
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df1, x='ff_avg_speed', y='k_percent', hue='year', palette='viridis', alpha=0.7)
plt.title('Fastball Velocity vs. Strikeout Rate (2024-2025)')
plt.xlabel('Average Fastball Velocity (MPH)')
plt.ylabel('Strikeout %')
plt.show()

# Distribution of ERA to identify elite performers
plt.figure(figsize=(8, 5))
sns.histplot(df1['p_era'], kde=True, color='blue')
plt.title('Distribution of Pitcher ERA Across the Dataset')
plt.axvline(df1['p_era'].mean(), color='red', linestyle='--', label='Mean ERA')
plt.legend()
plt.show()

# %%
# ============================================================
# INFERENTIAL STATISTICS: Actual Results vs. Expected Skill
# ============================================================

# Define "Luck" as the difference between actual wOBA and expected xwOBA
df2['woba_diff'] = df2['woba'] - df2['xwoba']

# Hypothesis Testing (T-test)
# Null Hypothesis (H0): There is no significant difference between actual wOBA and xwOBA.
# Alternative Hypothesis (Ha): There is a significant gap (indicating league-wide luck/misfortune).

t_stat, p_val = stats.ttest_rel(df2['woba'], df2['xwoba'])

print(f"Paired T-test Results for wOBA vs xwOBA:")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_val:.4f}")

if p_val < 0.05:
    print("Result: Reject the Null Hypothesis. There is a statistically significant difference.")
else:
    print("Result: Fail to reject the Null Hypothesis. Actual results align closely with expected skill.")
# Out:
# Paired T-test Results for wOBA vs xwOBA:
# T-statistic: -1.1049
# P-value: 0.2702
# Result: Fail to reject the Null Hypothesis. Actual results align closely with expected skill.

# %%
# ============================================================
# FEATURE SELECTION: Plate Discipline Drivers
# ============================================================

discipline_metrics = ['k_percent', 'bb_percent', 'whiff_percent', 'z_swing_percent', 'oz_swing_percent']
target = 'xwoba'

# Rank correlations
discipline_corr = df2[discipline_metrics + [target]].corr()[target].sort_values(ascending=False)
print("Plate Discipline Correlation with xwOBA:")
print(discipline_corr)

# Visualizing Whiff % Impact
plt.figure(figsize=(8, 6))
sns.boxplot(x='year', y='whiff_percent', data=df2)
plt.title('Year-over-Year Change in Whiff % (2024 vs 2025)')
plt.show()
# Out:
# Plate Discipline Correlation with xwOBA:
# xwoba               1.000000
# bb_percent          0.566007
# whiff_percent       0.185938
# z_swing_percent     0.057337
# k_percent           0.035206
# oz_swing_percent   -0.235713
# Name: xwoba, dtype: float64

# %%
# ============================================================
#STEP 4: PREPROCESSING AND TRAINING DATA DEVELOPMENT
# ============================================================
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# 1. Define all possible features based on your Proposal and Notebook
# We use the column names confirmed in your EDA notebook
target = 'xwoba'
potential_features = [
    'barrel_batted_rate', 'hard_hit_percent', 'avg_best_speed',  # Batted Ball Quality
    'whiff_percent', 'k_percent', 'bb_percent',                 # Plate Discipline
    'xslg', 'xobp',                                             # Expected Baselines
    'ff_avg_speed', 'sl_avg_speed', 'ch_avg_speed'              # Pitch Metrics
]

# FIX: Only use features that are actually in your dataframe (e.g., df2 or df1)
# Replace 'df2' with 'df1' if you haven't created a df2 yet.
active_df = df2 

features = [f for f in potential_features if f in active_df.columns]
print(f"Features found in dataset: {features}")

# 2. Ensure we only use rows where the target and features are not null
df_model = active_df.dropna(subset=[target] + features)

X = df_model[features]
y = df_model[target]

# 3. Standardize numeric features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled_df = pd.DataFrame(X_scaled, columns=features)

# 4. Split into training and testing sets (80/20 split)
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled_df, y, test_size=0.20, random_state=42
)

# 5. Review results
print(f"Final training set shape: {X_train.shape}")
# Out:
# Features found in dataset: ['barrel_batted_rate', 'hard_hit_percent', 'avg_best_speed', 'whiff_percent', 'k_percent', 'bb_percent', 'xslg', 'xobp']
# Final training set shape: (218, 8)

# %%
# ============================================================
# STEP 5: MODELING
# ============================================================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import GridSearchCV

# 1. Initialize models
# We will compare a baseline Linear Regression, a Random Forest, and Gradient Boosting.
lr_model = LinearRegression()
rf_model = RandomForestRegressor(random_state=42)
gb_model = GradientBoostingRegressor(random_state=42)

models = {
    "Linear Regression": lr_model,
    "Random Forest": rf_model,
    "Gradient Boosting": gb_model
}

# 2. Fit and Evaluate Models
model_results = []

for name, model in models.items():
    # Fit the model
    model.fit(X_train, y_train)
    
    # Make predictions
    y_pred = model.predict(X_test)
    
    # Calculate metrics
    mae = mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    
    model_results.append({
        "Model": name,
        "MAE": mae,
        "RMSE": rmse,
        "R2 Score": r2
    })

# Display Results
results_df = pd.DataFrame(model_results).sort_values(by="R2 Score", ascending=False)
print("Initial Model Comparison:")
print(results_df)

# 3. Hyperparameter Tuning (using GridSearchCV on Random Forest)
# We choose Random Forest for tuning as it often provides a strong balance of performance and stability.
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'max_features': ['sqrt', 'log2']
}

print("\nStarting Hyperparameter Tuning for Random Forest...")
grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, 
                           cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search.fit(X_train, y_train)

best_rf = grid_search.best_estimator_
print(f"Best Parameters: {grid_search.best_params_}")

# 4. Final Evaluation of Best Model
y_pred_final = best_rf.predict(X_test)
final_mae = mean_absolute_error(y_test, y_pred_final)
final_r2 = r2_score(y_test, y_pred_final)

print(f"\nFinal Best Model (Tuned Random Forest) Results:")
print(f"MAE: {final_mae:.4f}")
print(f"R2 Score: {final_r2:.4f}")

# 5. Visualizing Model Performance
plt.figure(figsize=(10, 5))

# Plot 1: Predicted vs Actual
plt.subplot(1, 2, 1)
plt.scatter(y_test, y_pred_final, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.xlabel('Actual xwOBA')
plt.ylabel('Predicted xwOBA')
plt.title('Predicted vs. Actual')

# Plot 2: Feature Importance
plt.subplot(1, 2, 2)
importances = best_rf.feature_importances_
feat_importances = pd.Series(importances, index=X_train.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.title('Top 10 Feature Importances')

plt.tight_layout()
plt.show()
# Out:
# Initial Model Comparison:
#                Model       MAE      RMSE  R2 Score
# 0  Linear Regression  0.001380  0.001803  0.997278
# 2  Gradient Boosting  0.003347  0.005570  0.974015
# 1      Random Forest  0.003508  0.005690  0.972884
#
# Starting Hyperparameter Tuning for Random Forest...
# Best Parameters: {'max_depth': 10, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 200}
#
# Final Best Model (Tuned Random Forest) Results:
# MAE: 0.0045
# R2 Score: 0.9544
